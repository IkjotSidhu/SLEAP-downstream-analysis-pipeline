# %%
from sleap_plotting import plotting_SLEAP, AnalysisConfig

# Run complete analysis pipeline
results = plotting_SLEAP(
    file_path="/Users/ikjot.sidhu/Desktop/SLEAP-Projects/lab-meeting-July25/Minerva-files/H5-files/labels.v020.slp.250730_022814.predictions.000_NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis.h5",
    main_node="bodycenter",  # Choose your node of interest
    fps=30,
    output_dir="./analysis_results"
)

print("Analysis complete!")
print(f"Analyzed {len(results['node_names'])} nodes")
print(f"Missing data: {results['summary']['missing_data_percentage']:.2f}%")
# Out:
# ===filename===
# /Users/ikjot.sidhu/Desktop/SLEAP-Projects/lab-meeting-July25/Minerva-files/H5-files/labels.v020.slp.250730_022814.predictions.000_NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis.h5
#
# ===HDF5 datasets===
# ['edge_inds', 'edge_names', 'instance_scores', 'labels_path', 'node_names', 'point_scores', 'provenance', 'track_names', 'track_occupancy', 'tracking_scores', 'tracks', 'video_ind', 'video_path']
#
# ===locations data shape===
# (52377, 10, 2, 2)
#
# ===nodes===
# 0: nose1
# 1: neck1
# 2: earL1
# 3: earR1
# 4: forelegL1
# 5: forelegR1
# 6: tailstart1
# 7: hindlegL1
# 8: hindlegR1
# 9: bodycenter
#
# frame count: 52377
# node count: 10
# instance count: 2
# Data Summary:
# - Frames: 52377
# - Nodes: 10
# - Instances: 2
# - Missing data: 0.00%
# Analysis complete!
# Analyzed 10 nodes
# Missing data: 0.00%
