# %%
from sleap_plotting import plotting_SLEAP, AnalysisConfig

# Run complete analysis pipeline
results = plotting_SLEAP(
    file_path="/Users/ikjot.sidhu/Desktop/SLEAP-Projects/JM95-100/H5-format-prediction-files/combined.JM95-100.labels.v5.slp.251016_123624.predictions.000_NL2_JM100_07-01-2025_12-59-27 JM100 0-1h IMQ.analysis.h5",
    main_node="bodycenter",  # Choose your node of interest
    fps=30,
    output_dir="./NL2_JM100_0-1h.analysis_results"
)

print("Analysis complete!")
print(f"Analyzed {len(results['node_names'])} nodes")
print(f"Missing data: {results['summary']['missing_data_percentage']:.2f}%")
# Out:
# ===filename===
# /Users/ikjot.sidhu/Desktop/SLEAP-Projects/JM95-100/H5-format-prediction-files/combined.JM95-100.labels.v5.slp.251016_123624.predictions.000_NL2_JM100_07-01-2025_12-59-27 JM100 0-1h IMQ.analysis.h5
#
# ===HDF5 datasets===
# ['edge_inds', 'edge_names', 'instance_scores', 'labels_path', 'node_names', 'point_scores', 'provenance', 'track_names', 'track_occupancy', 'tracking_scores', 'tracks', 'video_ind', 'video_path']
#
# ===locations data shape===
# (108209, 10, 2, 2)
#
# ===nodes===
# 0: nose1
# 1: neck1
# 2: earL1
# 3: earR1
# 4: forelegL1
# 5: forelegR1
# 6: tailstart1
# 7: hindlegL1
# 8: hindlegR1
# 9: bodycenter
#
# frame count: 108209
# node count: 10
# instance count: 2
# Data Summary:
# - Frames: 108209
# - Nodes: 10
# - Instances: 2
# - Missing data: 0.00%
#
# Trajectory data saved to: ./NL2_JM100_0-1h.analysis_results/bodycenter_trajectories.csv
# Trajectory data (by seconds) saved to: ./NL2_JM100_0-1h.analysis_results/bodycenter_trajectories_by_seconds.csv
# ...

# %%
from sleap_plotting import plotting_SLEAP, AnalysisConfig

# Run complete analysis pipeline
results = plotting_SLEAP(
    file_path="/Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Minerva-files/H5-files/labels.v020.slp.250730_022814.predictions.000_NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis.h5",
    main_node="bodycenter",  # Choose your node of interest
    fps=30,
    output_dir="./NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis_results"
)

print("Analysis complete!")
print(f"Analyzed {len(results['node_names'])} nodes")
print(f"Missing data: {results['summary']['missing_data_percentage']:.2f}%")
# Out:
# ===filename===
# /Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Minerva-files/H5-files/labels.v020.slp.250730_022814.predictions.000_NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis.h5
#
# ===HDF5 datasets===
# ['edge_inds', 'edge_names', 'instance_scores', 'labels_path', 'node_names', 'point_scores', 'provenance', 'track_names', 'track_occupancy', 'tracking_scores', 'tracks', 'video_ind', 'video_path']
#
# ===locations data shape===
# (52377, 10, 2, 2)
#
# ===nodes===
# 0: nose1
# 1: neck1
# 2: earL1
# 3: earR1
# 4: forelegL1
# 5: forelegR1
# 6: tailstart1
# 7: hindlegL1
# 8: hindlegR1
# 9: bodycenter
#
# frame count: 52377
# node count: 10
# instance count: 2
# Data Summary:
# - Frames: 52377
# - Nodes: 10
# - Instances: 2
# - Missing data: 0.00%
#
# Trajectory data saved to: ./NL1_04-30-2025_12-00-50 IMQ-_chopped.analysis_results/bodycenter_trajectories.csv
# ...

# %%
from sleap_plotting import plotting_SLEAP, AnalysisConfig

# Run complete analysis pipeline
results = plotting_SLEAP(
    file_path="/Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Analysis-part2/Predictions/labels.v001.001_NL1_07-01-2025_12-48-03 JM100 IMQ 0-3h.analysis.h5",
    main_node="bodycenter",  # Choose your node of interest
    fps=30,
    output_dir="./NL1_07-01-2025_12-48-03-JM100-IMQ-0-3h_results"
)

print("Analysis complete!")
print(f"Analyzed {len(results['node_names'])} nodes")
print(f"Missing data: {results['summary']['missing_data_percentage']:.2f}%")
# Out:
# ===filename===
# /Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Analysis-part2/Predictions/labels.v001.001_NL1_07-01-2025_12-48-03 JM100 IMQ 0-3h.analysis.h5
#
# ===HDF5 datasets===
# ['edge_inds', 'edge_names', 'instance_scores', 'labels_path', 'node_names', 'point_scores', 'provenance', 'track_names', 'track_occupancy', 'tracking_scores', 'tracks', 'video_ind', 'video_path']
#
# ===locations data shape===
# (324154, 10, 2, 2)
#
# ===nodes===
# 0: nose1
# 1: neck1
# 2: earL1
# 3: earR1
# 4: forelegL1
# 5: forelegR1
# 6: tailstart1
# 7: hindlegL1
# 8: hindlegR1
# 9: bodycenter
#
# frame count: 324154
# node count: 10
# instance count: 2
# Data Summary:
# - Frames: 324154
# - Nodes: 10
# - Instances: 2
# - Missing data: 0.00%
#
# Trajectory data saved to: ./NL1_07-01-2025_12-48-03-JM100-IMQ-0-3h_results/bodycenter_trajectories.csv
# Trajectory data (by seconds) saved to: ./NL1_07-01-2025_12-48-03-JM100-IMQ-0-3h_results/bodycenter_trajectories_by_seconds.csv
# ...

# %%
from sleap_plotting import plotting_SLEAP, AnalysisConfig

# Run complete analysis pipeline
results = plotting_SLEAP(
    file_path="/Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Analysis-part2/Predictions/labels.v001.000_NL2_07-01-2025_12-59-27 JM100 0-3h IMQ.analysis.h5",
    main_node="bodycenter",  # Choose your node of interest
    fps=30,
    output_dir="./NL2_07-01-2025_12-59-27-JM100-IMQ-0-3h_results"
)

print("Analysis complete!")
print(f"Analyzed {len(results['node_names'])} nodes")
print(f"Missing data: {results['summary']['missing_data_percentage']:.2f}%")
# Out:
# ===filename===
# /Users/ikjot.sidhu/Desktop/SLEAP-Projects/SLEAP-analysis-files/Analysis-part2/Predictions/labels.v001.000_NL2_07-01-2025_12-59-27 JM100 0-3h IMQ.analysis.h5
#
# ===HDF5 datasets===
# ['edge_inds', 'edge_names', 'instance_scores', 'labels_path', 'node_names', 'point_scores', 'provenance', 'track_names', 'track_occupancy', 'tracking_scores', 'tracks', 'video_ind', 'video_path']
#
# ===locations data shape===
# (324147, 10, 2, 2)
#
# ===nodes===
# 0: nose1
# 1: neck1
# 2: earL1
# 3: earR1
# 4: forelegL1
# 5: forelegR1
# 6: tailstart1
# 7: hindlegL1
# 8: hindlegR1
# 9: bodycenter
#
# frame count: 324147
# node count: 10
# instance count: 2
# Data Summary:
# - Frames: 324147
# - Nodes: 10
# - Instances: 2
# - Missing data: 0.00%
#
# Trajectory data saved to: ./NL2_07-01-2025_12-59-27-JM100-IMQ-0-3h_results/bodycenter_trajectories.csv
# Trajectory data (by seconds) saved to: ./NL2_07-01-2025_12-59-27-JM100-IMQ-0-3h_results/bodycenter_trajectories_by_seconds.csv
# ...
